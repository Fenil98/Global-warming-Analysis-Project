# %% [markdown]
# # EDA for energy use dataset

# %% [markdown]
# We found this dataset [here](https://data.worldbank.org/indicator/EG.USE.PCAP.KG.OE)
#
#     Energy use refers to the use of primary energy before transformation to other end-use fuels, which is equal to indigenous production plus imports and stock changes, minus exports and fuels supplied to ships and aircraft engaged in international transport.

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Import Dataset

# %%
energy = pd.read_csv("Energy_data.csv", skiprows = 3)

# %% [markdown]
# ## 3. Show Dataset

# %%
energy
# Out:
#      Country Name Country Code                                Indicator Name  \
# 0           Aruba          ABW  Energy use (kg of oil equivalent per capita)
# 1     Afghanistan          AFG  Energy use (kg of oil equivalent per capita)
# 2          Angola          AGO  Energy use (kg of oil equivalent per capita)
# 3         Albania          ALB  Energy use (kg of oil equivalent per capita)
# 4         Andorra          AND  Energy use (kg of oil equivalent per capita)
# ..            ...          ...                                           ...
# 259        Kosovo          XKX  Energy use (kg of oil equivalent per capita)
# 260   Yemen, Rep.          YEM  Energy use (kg of oil equivalent per capita)
# 261  South Africa          ZAF  Energy use (kg of oil equivalent per capita)
# 262        Zambia          ZMB  Energy use (kg of oil equivalent per capita)
# 263      Zimbabwe          ZWE  Energy use (kg of oil equivalent per capita)
#
# ...

# %% [markdown]
# ## 4. Basic EDA

# %% [markdown]
# - **To get first 5 rows of dataset**

# %%
energy.head()
# Out:
#   Country Name Country Code                                Indicator Name  \
# 0        Aruba          ABW  Energy use (kg of oil equivalent per capita)
# 1  Afghanistan          AFG  Energy use (kg of oil equivalent per capita)
# 2       Angola          AGO  Energy use (kg of oil equivalent per capita)
# 3      Albania          ALB  Energy use (kg of oil equivalent per capita)
# 4      Andorra          AND  Energy use (kg of oil equivalent per capita)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  ...        2011  \
# 0  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN  ...         NaN
# 1  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN  ...         NaN
# 2  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN  ...  521.780681
# 3  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN  ...  764.968617
# 4  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN  ...         NaN
#
#          2012        2013        2014  2015  2016  2017  2018  2019  2020
# ...

# %% [markdown]
# - **To get bottom 5 rows of dataset**

# %%
energy.tail()
# Out:
#      Country Name Country Code                                Indicator Name  \
# 259        Kosovo          XKX  Energy use (kg of oil equivalent per capita)
# 260   Yemen, Rep.          YEM  Energy use (kg of oil equivalent per capita)
# 261  South Africa          ZAF  Energy use (kg of oil equivalent per capita)
# 262        Zambia          ZMB  Energy use (kg of oil equivalent per capita)
# 263      Zimbabwe          ZWE  Energy use (kg of oil equivalent per capita)
#
#         Indicator Code  1960  1961  1962  1963  1964  1965  ...         2011  \
# 259  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN  ...  1411.472920
# 260  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN  ...   277.833521
# 261  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN  ...  2716.681173
# 262  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN  ...   619.400803
# 263  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN  ...   795.054503
#
# ...

# %%
type(energy)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - **To show all the column names of dataset**

# %%
energy.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %% [markdown]
# - **To fetch any perticular column from dataset**

# %%
energy['Country Code']
# Out:
# 0      ABW
# 1      AFG
# 2      AGO
# 3      ALB
# 4      AND
#       ...
# 259    XKX
# 260    YEM
# 261    ZAF
# 262    ZMB
# 263    ZWE
# Name: Country Code, Length: 264, dtype: object

# %%
type(energy['Country Code'])
# Out:
# pandas.core.series.Series

# %%
energy.shape
# Out:
# (264, 65)

# %%
energy.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count     31.000000     31.000000     31.000000     31.000000     31.000000
# mean    2386.063892   2419.869665   2520.566675   2655.287306   2763.369152
# std     1997.273938   1981.729409   1971.479905   1992.374328   2089.277325
# min      289.057068    322.490578    350.101258    367.811430    410.251827
# 25%     1401.298841   1455.073396   1568.387031   1725.539624   1791.042749
# 50%     1906.174930   1937.644745   2081.011621   2268.427890   2341.146313
# 75%     2790.132527   2820.343263   2939.735598   3101.964871   3222.519084
# max    10523.406690  10534.018210  10414.540920  10465.813020  11150.050340
#
#                1965          1966          1967          1968          1969  \
# count     32.000000     32.000000     32.000000     32.000000     32.000000
# mean    2807.812550   2887.442220   2970.598384   3159.132626   3344.209238
# ...

# %% [markdown]
# - **To know how many unique values are there in each columns of dataset**

# %%
energy.nunique()
# Out:
# Country Name      264
# Country Code      264
# Indicator Name      1
# Indicator Code      1
# 1960               31
#                  ...
# 2016                0
# 2017                0
# 2018                0
# 2019                0
# 2020                0
# Length: 65, dtype: int64

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 65 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    264 non-null    object
#  2   Indicator Name  264 non-null    object
#  3   Indicator Code  264 non-null    object
#  4   1960            31 non-null     float64
#  5   1961            31 non-null     float64
#  6   1962            31 non-null     float64
#  7   1963            31 non-null     float64
#  8   1964            31 non-null     float64
#  9   1965            32 non-null     float64
#  10  1966            32 non-null     float64
#  11  1967            32 non-null     float64
#  12  1968            32 non-null     float64
#  13  1969            32 non-null     float64
#  14  1970            32 non-null     float64
#  15  1971            149 non-null    float64
#  16  1972            149 non-null    float64
# ...

# %% [markdown]
# - **To know about corelation between each column of dataset**

# %%
energy.corr()
# Out:
#           1960      1961      1962      1963      1964      1965      1966  \
# 1960  1.000000  0.999722  0.999009  0.997393  0.997775  0.995332  0.990081
# 1961  0.999722  1.000000  0.999308  0.997583  0.998386  0.995896  0.990376
# 1962  0.999009  0.999308  1.000000  0.999309  0.999284  0.997923  0.993734
# 1963  0.997393  0.997583  0.999309  1.000000  0.999203  0.998903  0.995813
# 1964  0.997775  0.998386  0.999284  0.999203  1.000000  0.999071  0.995174
# ...        ...       ...       ...       ...       ...       ...       ...
# 2016       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2017       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2018       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2019       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2020       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %% [markdown]
# ## 5. To chceck missing, incomplete, or NULL value in each column

# %%
energy.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              233
#                  ...
# 2016              264
# 2017              264
# 2018              264
# 2019              264
# 2020              264
# Length: 65, dtype: int64

# %% [markdown]
# ## 6. To check outliers in the dataset

# %%
sns.boxplot(data = energy)
plt.title(' Outliers', color = 'blue', size = 18)
plt.xlabel('Columns', color = 'red')
plt.ylabel('Count', color = 'red')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## 7. energy in year 2010 for sample dataset of 5 country

# %%
sample = energy.sample(n = 5)

sample
# Out:
#                  Country Name Country Code  \
# 248                   Uruguay          URY
# 233              Turkmenistan          TKM
# 226  Turks and Caicos Islands          TCA
# 87                     Greece          GRC
# 200        Russian Federation          RUS
#
#                                    Indicator Name     Indicator Code  \
# 248  Energy use (kg of oil equivalent per capita)  EG.USE.PCAP.KG.OE
# 233  Energy use (kg of oil equivalent per capita)  EG.USE.PCAP.KG.OE
# 226  Energy use (kg of oil equivalent per capita)  EG.USE.PCAP.KG.OE
# 87   Energy use (kg of oil equivalent per capita)  EG.USE.PCAP.KG.OE
# 200  Energy use (kg of oil equivalent per capita)  EG.USE.PCAP.KG.OE
#
#            1960        1961        1962       1963        1964        1965  \
# 248         NaN         NaN         NaN        NaN         NaN         NaN
# 233         NaN         NaN         NaN        NaN         NaN         NaN
# ...

# %%
year = sample['2010']

cc = sample['Country Code']

# %%
plt.bar(cc, year)
plt.title('Energy usage in year 2010', color = 'blue', size = 18)
plt.xlabel('Country Code ', color = 'red', size = 12)
plt.ylabel('kg of oil per capita', color = 'red', size = 12)
# Out:
# Text(0, 0.5, 'kg of oil per capita')
