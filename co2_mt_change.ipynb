# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
co2_mt = pd.read_csv("C:\\Users\\fenil\\Desktop\\St Clair\\DAB-103-Analytical Tools & Decision Making\\Project\\Dataset\\CSV\\CO2 emissions (metric tons per capita).csv", skiprows = 3)

co2_mt
# Out:
#      Country Name Country Code                          Indicator Name  \
# 0           Aruba          ABW  CO2 emissions (metric tons per capita)
# 1     Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2          Angola          AGO  CO2 emissions (metric tons per capita)
# 3         Albania          ALB  CO2 emissions (metric tons per capita)
# 4         Andorra          AND  CO2 emissions (metric tons per capita)
# ..            ...          ...                                     ...
# 259        Kosovo          XKX  CO2 emissions (metric tons per capita)
# 260   Yemen, Rep.          YEM  CO2 emissions (metric tons per capita)
# 261  South Africa          ZAF  CO2 emissions (metric tons per capita)
# 262        Zambia          ZMB  CO2 emissions (metric tons per capita)
# 263      Zimbabwe          ZWE  CO2 emissions (metric tons per capita)
#
#      Indicator Code        1960        1961        1962        1963  \
# ...

# %%
cols = ['Country Name',
       '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
co2_mt_change = co2_mt[cols].set_index('Country Name').stack().reset_index()

co2_mt_change
# Out:
#       Country Name level_1           0
# 0            Aruba    1960  204.620372
# 1            Aruba    1961  208.822811
# 2            Aruba    1962  226.118079
# 3            Aruba    1963  214.800370
# 4            Aruba    1964  207.615777
# ...            ...     ...         ...
# 12980     Zimbabwe    2012    0.600303
# 12981     Zimbabwe    2013    0.881705
# 12982     Zimbabwe    2014    0.891739
# 12983     Zimbabwe    2015    0.891624
# 12984     Zimbabwe    2016    0.782777
#
# [12985 rows x 3 columns]

# %%
co2_mt_change.rename(
    columns=({ 'Country Name': 'country', 'level_1': 'year', 0:'CO2 Per Capita (metric tons)' }), 
    inplace=True,
)

co2_mt_change
# Out:
#         country  year  CO2 Per Capita (metric tons)
# 0         Aruba  1960                    204.620372
# 1         Aruba  1961                    208.822811
# 2         Aruba  1962                    226.118079
# 3         Aruba  1963                    214.800370
# 4         Aruba  1964                    207.615777
# ...         ...   ...                           ...
# 12980  Zimbabwe  2012                      0.600303
# 12981  Zimbabwe  2013                      0.881705
# 12982  Zimbabwe  2014                      0.891739
# 12983  Zimbabwe  2015                      0.891624
# 12984  Zimbabwe  2016                      0.782777
#
# [12985 rows x 3 columns]

# %%
co2_mt_change = co2_mt_change.astype({"country" : str, "year" : int})

# %%
co2_mt_change.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12985 entries, 0 to 12984
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       12985 non-null  object
#  1   year                          12985 non-null  int32
#  2   CO2 Per Capita (metric tons)  12985 non-null  float64
# dtypes: float64(1), int32(1), object(1)
# memory usage: 253.7+ KB

# %%
co2_mt_change.isnull().sum()
# Out:
# country                         0
# year                            0
# CO2 Per Capita (metric tons)    0
# dtype: int64

# %%
co2_mt_change.to_csv('C:\\Users\\fenil\\Desktop\\St Clair\\DAB-103-Analytical Tools & Decision Making\\Project\\Dataset\\Change\\co2_mt_change.csv')
