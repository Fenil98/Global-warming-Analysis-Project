# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gdp = pd.read_csv("C:\\Users\\fenil\\Desktop\\St Clair\\DAB-103-Analytical Tools & Decision Making\\Project\\Dataset\\CSV\\gdp_data.csv", skiprows = 3)

# %%
gdp
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
cols = ['Country Name',
       '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
gdp_change = gdp[cols].set_index('Country Name').stack().reset_index()

gdp_change
# Out:
#       Country Name level_1             0
# 0            Aruba    1986  4.054634e+08
# 1            Aruba    1987  4.876025e+08
# 2            Aruba    1988  5.964236e+08
# 3            Aruba    1989  6.953044e+08
# 4            Aruba    1990  7.648871e+08
# ...            ...     ...           ...
# 12396     Zimbabwe    2015  1.996312e+10
# 12397     Zimbabwe    2016  2.054868e+10
# 12398     Zimbabwe    2017  2.204090e+10
# 12399     Zimbabwe    2018  2.431156e+10
# 12400     Zimbabwe    2019  2.144076e+10
#
# [12401 rows x 3 columns]

# %%
gdp_change.rename(
    columns=({ 'Country Name': 'country', 'level_1': 'year', 0:'current GDP' }), 
    inplace=True,
)

gdp_change
# Out:
#         country  year   current GDP
# 0         Aruba  1986  4.054634e+08
# 1         Aruba  1987  4.876025e+08
# 2         Aruba  1988  5.964236e+08
# 3         Aruba  1989  6.953044e+08
# 4         Aruba  1990  7.648871e+08
# ...         ...   ...           ...
# 12396  Zimbabwe  2015  1.996312e+10
# 12397  Zimbabwe  2016  2.054868e+10
# 12398  Zimbabwe  2017  2.204090e+10
# 12399  Zimbabwe  2018  2.431156e+10
# 12400  Zimbabwe  2019  2.144076e+10
#
# [12401 rows x 3 columns]

# %%
gdp_change = gdp_change.astype({"country" : str, "year" : int})

# %%
gdp_change.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12401 entries, 0 to 12400
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      12401 non-null  object
#  1   year         12401 non-null  int32
#  2   current GDP  12401 non-null  float64
# dtypes: float64(1), int32(1), object(1)
# memory usage: 242.3+ KB

# %%
gdp_change.isnull().sum()
# Out:
# country        0
# year           0
# current GDP    0
# dtype: int64

# %%
gdp_change.to_csv('C:\\Users\\fenil\\Desktop\\St Clair\\DAB-103-Analytical Tools & Decision Making\\Project\\Dataset\\Change\\gdp_change.csv')
